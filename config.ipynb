# %%
from pyspark.sql.types import *
from pyspark.sql import functions as F

# %%
catalog ='west_africa_conflict'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'

volume_path = '/Volumes/west_africa_conflict/bronze/acled_raw'
raw_file = '/Volumes/west_africa_conflict/bronze/acled_raw/GEDEvent_v25_1.csv'
